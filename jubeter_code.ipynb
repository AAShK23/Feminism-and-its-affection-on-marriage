# %% [markdown]
# <a href="https://colab.research.google.com/github/AAShK23/Feminism-and-its-affection-on-marriage/blob/main/jubeter_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# henani file csv bo naw project'aka w bakarhenanawa
mydata = pd.read_csv('Feminism and its affection on marriage - Form Responses.csv')

# %%
# zanyariakani naw file'aka
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 9 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   age                                                323 non-null    object
#  1   gendar                                             323 non-null    object
#  2   stage                                              317 non-null    float64
#  3   martial status                                     324 non-null    object
#  4   location                                           322 non-null    object
#  5   college                                            282 non-null    object
#  6   do you support feminism                            318 non-null    object
#  7   are a membet from womens organization?             323 non-null    object
#  8   does feminism affect divorce and family problems?  321 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 23.2+ KB

# %%
mydata.describe()
# Out:
#             stage
# count  317.000000
# mean     1.968454
# std      0.913479
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      5.000000

# %%
import matplotlib.pyplot as plt
mydata.hist(['stage'], figsize=(5,5))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="stage", y="age", data=mydata)
# Out:
# <AxesSubplot:xlabel='stage', ylabel='age'>

# %%
pd.crosstab(mydata['stage'],mydata['age'] )
# Out:
# age    18  19  20  21  21+
# stage
# 1.0    32  39  24   4    6
# 2.0     3  50  44  26   21
# 3.0     0   1  14  17   14
# 4.0     0   1   2   4   10
# 5.0     1   0   1   1    2

# %%
pd.crosstab(mydata['age'],mydata['are a membet from womens organization?'] )
# Out:
# are a membet from womens organization?  بەڵێ  نەخێر
# age
# 18                                         3     35
# 19                                         2     89
# 20                                         4     81
# 21                                         1     51
# 21+                                        0     56

# %%
sns.countplot(x="stage", hue="does feminism affect divorce and family problems?", data=mydata)
# Out:
# <AxesSubplot:xlabel='stage', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['stage', 'age'],
                     columns=[ 'location'], aggfunc=len)
# Out:
#           are a membet from womens organization?             college          \
# location                             دەرەوەی شار سلێمانی دەرەوەی شار سلێمانی
# stage age
# 1.0   18                                    20.0    12.0        20.0    12.0
#       19                                    24.0    14.0        24.0    14.0
#       20                                    13.0    11.0        13.0    11.0
#       21                                     3.0     1.0         3.0     1.0
#       21+                                    3.0     3.0         3.0     3.0
# 2.0   18                                     1.0     2.0         1.0     2.0
#       19                                     9.0    41.0         9.0    41.0
#       20                                     3.0    41.0         3.0    41.0
#       21                                     6.0    20.0         6.0    20.0
#       21+                                    6.0    15.0         6.0    15.0
# 3.0   19                                     1.0     NaN         1.0     NaN
#       20                                     8.0     6.0         8.0     6.0
#       21                                     3.0    14.0         3.0    14.0
#       21+                                    7.0     7.0         7.0     7.0
# 4.0   19                                     NaN     1.0         NaN     1.0
#       20                                     1.0     1.0         1.0     1.0
#       21                                     2.0     2.0         2.0     2.0
#       21+                                    5.0     5.0         5.0     5.0
# 5.0   18                                     NaN     1.0         NaN     1.0
#       20                                     1.0     NaN         1.0     NaN
#       21                                     1.0     NaN         1.0     NaN
#       21+                                    1.0     1.0         1.0     1.0
#
#           do you support feminism          \
# location              دەرەوەی شار سلێمانی
# stage age
# 1.0   18                     20.0    12.0
#       19                     24.0    14.0
#       20                     13.0    11.0
#       21                      3.0     1.0
#       21+                     3.0     3.0
# 2.0   18                      1.0     2.0
#       19                      9.0    41.0
#       20                      3.0    41.0
#       21                      6.0    20.0
#       21+                     6.0    15.0
# 3.0   19                      1.0     NaN
#       20                      8.0     6.0
#       21                      3.0    14.0
#       21+                     7.0     7.0
# 4.0   19                      NaN     1.0
#       20                      1.0     1.0
#       21                      2.0     2.0
#       21+                     5.0     5.0
# 5.0   18                      NaN     1.0
#       20                      1.0     NaN
#       21                      1.0     NaN
#       21+                     1.0     1.0
#
#           does feminism affect divorce and family problems?          \
# location                                        دەرەوەی شار سلێمانی
# stage age
# 1.0   18                                               20.0    12.0
#       19                                               24.0    14.0
#       20                                               13.0    11.0
#       21                                                3.0     1.0
#       21+                                               3.0     3.0
# 2.0   18                                                1.0     2.0
#       19                                                9.0    41.0
#       20                                                3.0    41.0
#       21                                                6.0    20.0
#       21+                                               6.0    15.0
# 3.0   19                                                1.0     NaN
#       20                                                8.0     6.0
#       21                                                3.0    14.0
#       21+                                               7.0     7.0
# 4.0   19                                                NaN     1.0
#       20                                                1.0     1.0
#       21                                                2.0     2.0
#       21+                                               5.0     5.0
# 5.0   18                                                NaN     1.0
#       20                                                1.0     NaN
#       21                                                1.0     NaN
#       21+                                               1.0     1.0
#
#                gendar         martial status
# location  دەرەوەی شار سلێمانی     دەرەوەی شار سلێمانی
# stage age
# 1.0   18         20.0    12.0            20.0    12.0
#       19         24.0    14.0            24.0    14.0
#       20         13.0    11.0            13.0    11.0
#       21          3.0     1.0             3.0     1.0
#       21+         3.0     3.0             3.0     3.0
# 2.0   18          1.0     2.0             1.0     2.0
#       19          9.0    41.0             9.0    41.0
#       20          3.0    41.0             3.0    41.0
#       21          6.0    20.0             6.0    20.0
#       21+         6.0    15.0             6.0    15.0
# 3.0   19          1.0     NaN             1.0     NaN
#       20          8.0     6.0             8.0     6.0
#       21          3.0    14.0             3.0    14.0
#       21+         7.0     7.0             7.0     7.0
# 4.0   19          NaN     1.0             NaN     1.0
#       20          1.0     1.0             1.0     1.0
#       21          2.0     2.0             2.0     2.0
#       21+         5.0     5.0             5.0     5.0
# 5.0   18          NaN     1.0             NaN     1.0
#       20          1.0     NaN             1.0     NaN
#       21          1.0     NaN             1.0     NaN
#       21+         1.0     1.0             1.0     1.0

# %%
pd.pivot_table(mydata,'age', index=['stage','gendar'],
                     columns=[ 'martial status '])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py:507: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
# Empty DataFrame
# Columns: []
# Index: [(1.0, مێ), (1.0, نێر), (2.0, مێ), (2.0, نێر), (3.0, مێ), (3.0, نێر), (4.0, مێ), (4.0, نێر), (5.0, مێ), (5.0, نێر)]

# %%
pd.pivot_table(mydata,'age', index=['stage', 'location'],
                     columns=[ 'college'])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py:507: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
# Empty DataFrame
# Columns: []
# Index: [(1.0, دەرەوەی شار), (1.0, سلێمانی), (2.0, دەرەوەی شار), (2.0, سلێمانی), (3.0, دەرەوەی شار), (3.0, سلێمانی), (4.0, دەرەوەی شار), (4.0, سلێمانی), (5.0, سلێمانی)]

# %%
sns.pairplot(mydata)

# %%
mydata['stage'].mean()
# Out:
# 1.9684542586750788

# %%
sns.histplot(mydata['location'])
# Out:
# <AxesSubplot:xlabel='location', ylabel='Count'>

# %%
mydata.hist(by='location',column = 'do you support feminism')
# Out:
# array([<AxesSubplot:title={'center':'دەرەوەی شار'}>,
#        <AxesSubplot:title={'center':'سلێمانی'}>], dtype=object)

# %%
mydata.hist(by='age',column ='does feminism affect divorce and family problems?')
# Out:
# array([[<AxesSubplot:title={'center':'18'}>,
#         <AxesSubplot:title={'center':'19'}>],
#        [<AxesSubplot:title={'center':'20'}>,
#         <AxesSubplot:title={'center':'21'}>],
#        [<AxesSubplot:title={'center':'21+'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
mydata.hist(by='age',column = 'college', figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'18'}>,
#         <AxesSubplot:title={'center':'19'}>],
#        [<AxesSubplot:title={'center':'20'}>,
#         <AxesSubplot:title={'center':'21'}>],
#        [<AxesSubplot:title={'center':'21+'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
corr = mydata.corr()
corr
# Out:
#        stage
# stage    1.0

# %%
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
